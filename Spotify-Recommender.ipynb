# %% [markdown]
# Spotify uses AI to recommend music to its users. You can try building a recommender system based on publicly available data on Spotify.
# Spotify has an API that you can use to retrieve audio data — you can find features like the year of release, key, popularity, and artist. To access this API in Python, you can use a library called Spotipy.
# You can also use the Spotify dataset on Kaggle that has around 600K rows. Using these datasets, you can suggest the best alternative to each user’s favourite musician. You can also come up with song recommendations based on the content and genre preferred by each user.
# This recommender system can be built using K-Means clustering — similar data points will be grouped. You can recommend songs with a minimal intra-cluster distance between them to the end-user.
# Once you have built the recommender system, you can also turn it into a simple Python app and deploy it. You can get users to enter their favourite songs on Spotify, then display your model recommendations on the screen that have the highest similarity to the songs they enjoyed.

# %% [markdown]
# Overview
#
# Part One: Create recommender system
# Talk to API
# - Launch Jupyter in environment (kernels?)
# - Authenticate by setting environment variables[X]
# - Get some info from API
# Prompt for fave musician
# Search for it
# Use Kmeans to find similar artists
# Suggest best alternative
#
# Part Two: Create app
# Prompt for favorite song(s?)
# Recommend highest similarity songs
#
# Questions
# What data will I ask for from the API?

# %%
birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'

results = sp.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])

# %%
artist_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP?si=p-tC6l6FTACajKY108Cwdg'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

results = spotify.artist_albums(artist_uri, album_type='album')
# albums = results['items']
# while results['next']:
#     results = spotify.next(results)
#     albums.extend(results['items'])

# for album in albums:
#     print(album['name'])

# %%
import pandas as pd

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth
import sys
import json
import time

scope = "user-library-read"

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope))

results = sp.current_user_saved_tracks()

# %%
for idx, item in enumerate(results['items']):
    track = item['track']
    print(idx, track['artists'][0]['name'], " – ", track['name'])
# Out:
# 0 $uicideboy$  –  Matte Black
# 1 Big Sean  –  It Is What It Is (feat. Gunna)
# 2 Future  –  PLUTOSKI
# 3 Don Toliver  –  LOVE IS A DRUG
# 4 Future  –  TEFLON DON
# 5 The Olympians  –  Pluto's Lament
# 6 Lil Tecca  –  Out Of Love (feat. Internet Money)
# 7 Jack Harlow  –  BIG CHILLIN
# 8 Young Thug  –  Millions
# 9 White Reaper  –  Daisies
# 10 Microwave  –  Lighterless
# 11 A$AP Rocky  –  Tailor Swif
# 12 A$AP Rocky  –  Ruby Rosary (feat. J. Cole)
# 13 Caribou  –  Volume
# 14 Fred again..  –  places to be
# 15 Westside Gunn  –  Shootouts In Soho (feat. A$AP Rocky & Stove God Cooks)
# 16 Disco Lines  –  RWEOK?
# 17 Sam Binga  –  AYO - Foreign Concept Remix
# 18 MOUNT WESTMORE  –  Big Subwoofer (feat. Snoop Dogg, Ice Cube, E-40 & Too $hort ) - Single Version
# 19 Eric B. & Rakim  –  Don't Sweat The Technique

# %%
artist_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP?si=p-tC6l6FTACajKY108Cwdg'
results = sp.artist_albums(artist_uri, album_type='album')
albums = results['items']
while results['next']:
    results = sp.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4800/1861850877.py in <module>
#       1 artist_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP?si=p-tC6l6FTACajKY108Cwdg'
#       2 results = sp.artist_albums(artist_uri, album_type='album')
# ----> 3 albums = results['items']
#       4 while results['next']:
#       5     results = sp.next(results)
#
# KeyError: 'items'

# %%
# shows audio analysis for the given track
import json
import time
import sys


client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

if len(sys.argv) > 1:
    tid = sys.argv[1]
else:
    tid = 'spotify:track:4TTV7EcfroSLWzXRY6gLv6'

start = time.time()
analysis = sp.audio_analysis(tid)
delta = time.time() - start
print(json.dumps(analysis, indent=4))
print(f"analysis retrieved in {delta:.2f} seconds")

# %%
# shows acoustic features for tracks for the given artist

from spotipy.oauth2 import SpotifyClientCredentials
import json
import spotipy
import time
import sys
from pprint import pprint

client_credentials_manager = SpotifyClientCredentials()
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace = False

if len(sys.argv) > 1:
    artist_name = ' '.join(sys.argv[1:])
else:
    artist_name = 'weezer'

results = sp.search(q=artist_name, limit=50)
tids = []
for i, t in enumerate(results['tracks']['items']):
    print(' ', i, t['name'])
    tids.append(t['uri'])

start = time.time()
features = sp.audio_features(tids)
delta = time.time() - start
for feature in features:
    print(json.dumps(feature, indent=4))
    print()
    analysis = sp._get(feature['analysis_url'])
    print(json.dumps(analysis, indent=4))
    print()
print(f"features retrieved in {delta:.2f} seconds")

# %% [markdown]
# Get all tracks from a playlist
# - get the playlist
# - get the tracks
# - put in dataframe

# %%
#Get playlist
# Shows a user's playlists (need to be authenticated via oauth)




if len(sys.argv) > 1:
    username = sys.argv[1]
else:
    print("Whoops, need a username!")
    print("usage: python user_playlists.py [username]")
    sys.exit()

#sp = spotipy.Spotify(auth_manager=SpotifyOAuth())
print(username)
playlists = sp.user_playlists(username)

for playlist in playlists['items']:
    print(playlist['name'])
# Out:
# -f

# %%
#Get playlist tracks

from pprint import pprint

sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials())

pl_id = 'spotify:playlist:3CprXA2nvM7q3dNlYAw8T7'
offset = 0

while True:
    response = sp.playlist_items(pl_id,
                                 offset=offset,
                                 fields='items.track.id,total',
                                 additional_types=['track'])

    if len(response['items']) == 0:
        break

    pprint(response['items'])
    offset = offset + len(response['items'])
    print(offset, "/", response['total'])

# %%
sp.current_user()
# Out:
# {'display_name': 'Joel Weber',
#  'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#  'href': 'https://api.spotify.com/v1/users/1216338953',
#  'id': '1216338953',
#  'images': [{'url': 'https://scontent-iad3-2.xx.fbcdn.net/v/t1.18169-1/1456771_739136052767720_441339196_n.jpg?stp=c2.18.659.659a_cp0_dst-jpg_s50x50&_nc_cat=105&ccb=1-7&_nc_sid=312bcd&_nc_ohc=ekeC09kjeyAQ7kNvgF38LLA&_nc_ht=scontent-iad3-2.xx&edm=AP4hL3IEAAAA&oh=00_AYCeKHMU_QgrwAAoj65tN6uJcPYBDOXjGgm-9QozXLiXdA&oe=672B65C4',
#    'height': 64,
#    'width': 64},
#   {'url': 'https://scontent-iad3-2.xx.fbcdn.net/v/t1.18169-1/1456771_739136052767720_441339196_n.jpg?stp=c2.18.659.659a_dst-jpg_s320x320&_nc_cat=105&ccb=1-7&_nc_sid=05c18e&_nc_ohc=ekeC09kjeyAQ7kNvgF38LLA&_nc_ht=scontent-iad3-2.xx&edm=AP4hL3IEAAAA&oh=00_AYAAI1IhJxQkNd_PyL9AAdhf94qT5Q4cvdGyleOuAomSXA&oe=672B65C4',
#    'height': 300,
#    'width': 300}],
#  'type': 'user',
#  'uri': 'spotify:user:1216338953',
#  'followers': {'href': None, 'total': 32}}

# %%
playlists = sp.current_user_playlists()

# %%
sp.current_user_playlists()

# %%
pl = playlists['items']

# %%
tenplaylists = sp.current_user_playlists(limit=10)

# %%
tenplaylists

# %%
fiveplaylists = sp.current_user_playlists(limit=5)

# %%
fiveplaylists
# Out:
# {'href': 'https://api.spotify.com/v1/users/1216338953/playlists?offset=0&limit=5',
#  'limit': 5,
#  'next': 'https://api.spotify.com/v1/users/1216338953/playlists?offset=5&limit=5',
#  'offset': 0,
#  'previous': None,
#  'total': 173,
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/4788Yhz25ETV8x8yROewmF'},
#    'href': 'https://api.spotify.com/v1/playlists/4788Yhz25ETV8x8yROewmF',
#    'id': '4788Yhz25ETV8x8yROewmF',
#    'images': [{'height': None,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02229411bccce65156241b6190',
#      'width': None}],
#    'name': '100th one (B-side)',
#    'owner': {'display_name': 'Joel Weber',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAABNP7quksHVtf85OacuOxdAwnXw1B',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/4788Yhz25ETV8x8yROewmF/tracks',
#     'total': 2},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:4788Yhz25ETV8x8yROewmF'},
#   {'collaborative': False,
#    'description': 'Started 7&#x2F;18&#x2F;24',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7AlwC5VBiUMfUPlKl0eRqz'},
#    'href': 'https://api.spotify.com/v1/playlists/7AlwC5VBiUMfUPlKl0eRqz',
#    'id': '7AlwC5VBiUMfUPlKl0eRqz',
#    'images': [{'height': None,
#      'url': 'https://image-cdn-ak.spotifycdn.com/image/ab67706c0000da84156c2bd7cbc252ba4d0b74a8',
#      'width': None}],
#    'name': '100th one',
#    'owner': {'display_name': 'Joel Weber',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAABd9oXW+SLo+npVSclSkQVVmwpM5h',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7AlwC5VBiUMfUPlKl0eRqz/tracks',
#     'total': 3},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7AlwC5VBiUMfUPlKl0eRqz'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/7bj5es8DWAf8nz90O7olSH'},
#    'href': 'https://api.spotify.com/v1/playlists/7bj5es8DWAf8nz90O7olSH',
#    'id': '7bj5es8DWAf8nz90O7olSH',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d00001e021190f1fbc1d55aa9397d9975ab67616d00001e0249f649f3c6b64f896ce34468ab67616d00001e02b4fd0fbcd4837ab4b491054dab67616d00001e02c5649add07ed3720be9d5526',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d00001e021190f1fbc1d55aa9397d9975ab67616d00001e0249f649f3c6b64f896ce34468ab67616d00001e02b4fd0fbcd4837ab4b491054dab67616d00001e02c5649add07ed3720be9d5526',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d00001e021190f1fbc1d55aa9397d9975ab67616d00001e0249f649f3c6b64f896ce34468ab67616d00001e02b4fd0fbcd4837ab4b491054dab67616d00001e02c5649add07ed3720be9d5526',
#      'width': 60}],
#    'name': '🌞 ⛱️',
#    'owner': {'display_name': 'Joel Weber',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAKpTzp6wJwxLqvedKPQk+R+5lRGKb',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/7bj5es8DWAf8nz90O7olSH/tracks',
#     'total': 41},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:7bj5es8DWAf8nz90O7olSH'},
#   {'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/2tCc6aPlfCBtKyJq1UrC2Q'},
#    'href': 'https://api.spotify.com/v1/playlists/2tCc6aPlfCBtKyJq1UrC2Q',
#    'id': '2tCc6aPlfCBtKyJq1UrC2Q',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d00001e022e5a021780f5056724a5b6afab67616d00001e024158fe41143182ec16ead070ab67616d00001e0282cba32f141144974267a134ab67616d00001e02eaf06b889f4c8055dde0e5ff',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d00001e022e5a021780f5056724a5b6afab67616d00001e024158fe41143182ec16ead070ab67616d00001e0282cba32f141144974267a134ab67616d00001e02eaf06b889f4c8055dde0e5ff',
#      'width': 300},
#     {'height': 60,
#      'url': 'https://mosaic.scdn.co/60/ab67616d00001e022e5a021780f5056724a5b6afab67616d00001e024158fe41143182ec16ead070ab67616d00001e0282cba32f141144974267a134ab67616d00001e02eaf06b889f4c8055dde0e5ff',
#      'width': 60}],
#    'name': '🎮',
#    'owner': {'display_name': 'Joel Weber',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'AAAAQNmReqAP/Q42MFV6TP1W2p2X8OID',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/2tCc6aPlfCBtKyJq1UrC2Q/tracks',
#     'total': 245},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:2tCc6aPlfCBtKyJq1UrC2Q'},
#   {'collaborative': False,
#    'description': 'Spotify Wrapped presents the songs you loved this year.',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1Fa1IIVtEpGUcU'},
#    'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1Fa1IIVtEpGUcU',
#    'id': '37i9dQZF1Fa1IIVtEpGUcU',
#    'images': [{'height': None,
#      'url': 'https://wrapped-images.spotifycdn.com/image/yts-2023/default/your-top-songs-2023_DEFAULT_en.jpg',
#      'width': None}],
#    'name': 'Your Top Songs 2023',
#    'owner': {'display_name': 'Spotify',
#     'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#     'href': 'https://api.spotify.com/v1/users/spotify',
#     'id': 'spotify',
#     'type': 'user',
#     'uri': 'spotify:user:spotify'},
#    'primary_color': None,
#    'public': True,
#    'snapshot_id': 'ZVPI2AAAAAD0+Af8jvnvW5Rlb9UA+FT5',
#    'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1Fa1IIVtEpGUcU/tracks',
#     'total': 100},
#    'type': 'playlist',
#    'uri': 'spotify:playlist:37i9dQZF1Fa1IIVtEpGUcU'}]}

# %%
f=fiveplaylists['items']

# %%
pd.json_normalize(fiveplaylists, max_level=1)
# Out:
#                                                 href  limit  \
# 0  https://api.spotify.com/v1/users/1216338953/pl...      5
#
#                                                 next  offset previous  total  \
# 0  https://api.spotify.com/v1/users/1216338953/pl...       0     None    173
#
#                                                items
# 0  [{'collaborative': False, 'description': '', '...

# %%
pd.json_normalize(fiveplaylists)
# Out:
#                                                 href  limit  \
# 0  https://api.spotify.com/v1/users/1216338953/pl...      5
#
#                                                 next  offset previous  total  \
# 0  https://api.spotify.com/v1/users/1216338953/pl...       0     None    173
#
#                                                items
# 0  [{'collaborative': False, 'description': '', '...

# %%
pd.DataFrame(f)
# Out:
#    collaborative                                        description  \
# 0          False
# 1          False                          Started 7&#x2F;18&#x2F;24
# 2          False
# 3          False
# 4          False  Spotify Wrapped presents the songs you loved t...
#
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/playlist...
# 1  {'spotify': 'https://open.spotify.com/playlist...
# 2  {'spotify': 'https://open.spotify.com/playlist...
# 3  {'spotify': 'https://open.spotify.com/playlist...
# 4  {'spotify': 'https://open.spotify.com/playlist...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/playlists/4788Yhz25...  4788Yhz25ETV8x8yROewmF
# 1  https://api.spotify.com/v1/playlists/7AlwC5VBi...  7AlwC5VBiUMfUPlKl0eRqz
# 2  https://api.spotify.com/v1/playlists/7bj5es8DW...  7bj5es8DWAf8nz90O7olSH
# 3  https://api.spotify.com/v1/playlists/2tCc6aPlf...  2tCc6aPlfCBtKyJq1UrC2Q
# 4  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1Fa1IIVtEpGUcU
#
#                                               images                 name  \
# 0  [{'height': None, 'url': 'https://i.scdn.co/im...   100th one (B-side)
# 1  [{'height': None, 'url': 'https://image-cdn-ak...            100th one
# 2  [{'height': 640, 'url': 'https://mosaic.scdn.c...                 🌞 ⛱️
# 3  [{'height': 640, 'url': 'https://mosaic.scdn.c...                    🎮
# 4  [{'height': None, 'url': 'https://wrapped-imag...  Your Top Songs 2023
#
#                                                owner primary_color  public  \
# 0  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 1  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 2  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 3  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 4  {'display_name': 'Spotify', 'external_urls': {...          None    True
#
#                         snapshot_id  \
# 0  AAAABNP7quksHVtf85OacuOxdAwnXw1B
# 1  AAAABd9oXW+SLo+npVSclSkQVVmwpM5h
# 2  AAAAKpTzp6wJwxLqvedKPQk+R+5lRGKb
# 3  AAAAQNmReqAP/Q42MFV6TP1W2p2X8OID
# 4  ZVPI2AAAAAD0+Af8jvnvW5Rlb9UA+FT5
#
#                                               tracks      type  \
# 0  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 1  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 2  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 3  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 4  {'href': 'https://api.spotify.com/v1/playlists...  playlist
#
#                                        uri
# 0  spotify:playlist:4788Yhz25ETV8x8yROewmF
# 1  spotify:playlist:7AlwC5VBiUMfUPlKl0eRqz
# 2  spotify:playlist:7bj5es8DWAf8nz90O7olSH
# 3  spotify:playlist:2tCc6aPlfCBtKyJq1UrC2Q
# 4  spotify:playlist:37i9dQZF1Fa1IIVtEpGUcU

# %%
pd.DataFrame(pl)
# Out:
#     collaborative                                        description  \
# 0           False
# 1           False                          Started 7&#x2F;18&#x2F;24
# 2           False
# 3           False
# 4           False  Spotify Wrapped presents the songs you loved t...
# 5           False
# 6           False  The best tunes in Jazz history. Cover: Wayne S...
# 7           False
# 8           False           New jazz for open minds. Cover: Kokoroko
# 9           False
# 10          False
# 11          False  House music lives here. United under one roof,...
# 12          False  The best new music every Friday. Cover: Bartee...
# 13          False  A selection of the greatest classical tunes; t...
# 14          False  Lend a little drama to the occasion with this ...
# 15          False
# 16          False
# 17          False
# 18          False
# 19          False
# 20          False
# 21          False  FKA twigs, Earthgang, Denzel, Django, Oliver T...
# 22          False  Rick Ross, Wiz, Doja Cat, Yves Tumor, Injury R...
# 23          False
# 24          False  Mac, Zack Fox, Thugger, Don Toliver, TompaBeat...
# 25          False  Flylo, Glass Animals, Uzi, Nas, Like 4 Alchemi...
# 26          False  Dayglow, Trippie Redd, Drake, J Balvin, Baby K...
# 27          False  Various Reggaeton, Unce Unce EDM, Tyler, Ski M...
# 28          False
# 29          False
# 30          False
# 31          False
# 32          False                                        big Gameing
# 33          False
# 34          False  Gunna, Trippie Redd, James Blake, Ariana Grand...
# 35          False
# 36          False
# 37          False
# 38          False
# 39          False
# 40          False
# 41          False
# 42          False
# 43          False
# 44          False
# 45          False
# 46          False
# 47          False
# 48          False
# 49          False                                    beeg beeg butts
#
#                                         external_urls  \
# 0   {'spotify': 'https://open.spotify.com/playlist...
# 1   {'spotify': 'https://open.spotify.com/playlist...
# 2   {'spotify': 'https://open.spotify.com/playlist...
# 3   {'spotify': 'https://open.spotify.com/playlist...
# 4   {'spotify': 'https://open.spotify.com/playlist...
# 5   {'spotify': 'https://open.spotify.com/playlist...
# 6   {'spotify': 'https://open.spotify.com/playlist...
# 7   {'spotify': 'https://open.spotify.com/playlist...
# 8   {'spotify': 'https://open.spotify.com/playlist...
# 9   {'spotify': 'https://open.spotify.com/playlist...
# 10  {'spotify': 'https://open.spotify.com/playlist...
# 11  {'spotify': 'https://open.spotify.com/playlist...
# 12  {'spotify': 'https://open.spotify.com/playlist...
# 13  {'spotify': 'https://open.spotify.com/playlist...
# 14  {'spotify': 'https://open.spotify.com/playlist...
# 15  {'spotify': 'https://open.spotify.com/playlist...
# 16  {'spotify': 'https://open.spotify.com/playlist...
# 17  {'spotify': 'https://open.spotify.com/playlist...
# 18  {'spotify': 'https://open.spotify.com/playlist...
# 19  {'spotify': 'https://open.spotify.com/playlist...
# 20  {'spotify': 'https://open.spotify.com/playlist...
# 21  {'spotify': 'https://open.spotify.com/playlist...
# 22  {'spotify': 'https://open.spotify.com/playlist...
# 23  {'spotify': 'https://open.spotify.com/playlist...
# 24  {'spotify': 'https://open.spotify.com/playlist...
# 25  {'spotify': 'https://open.spotify.com/playlist...
# 26  {'spotify': 'https://open.spotify.com/playlist...
# 27  {'spotify': 'https://open.spotify.com/playlist...
# 28  {'spotify': 'https://open.spotify.com/playlist...
# 29  {'spotify': 'https://open.spotify.com/playlist...
# 30  {'spotify': 'https://open.spotify.com/playlist...
# 31  {'spotify': 'https://open.spotify.com/playlist...
# 32  {'spotify': 'https://open.spotify.com/playlist...
# 33  {'spotify': 'https://open.spotify.com/playlist...
# 34  {'spotify': 'https://open.spotify.com/playlist...
# 35  {'spotify': 'https://open.spotify.com/playlist...
# 36  {'spotify': 'https://open.spotify.com/playlist...
# 37  {'spotify': 'https://open.spotify.com/playlist...
# 38  {'spotify': 'https://open.spotify.com/playlist...
# 39  {'spotify': 'https://open.spotify.com/playlist...
# 40  {'spotify': 'https://open.spotify.com/playlist...
# 41  {'spotify': 'https://open.spotify.com/playlist...
# 42  {'spotify': 'https://open.spotify.com/playlist...
# 43  {'spotify': 'https://open.spotify.com/playlist...
# 44  {'spotify': 'https://open.spotify.com/playlist...
# 45  {'spotify': 'https://open.spotify.com/playlist...
# 46  {'spotify': 'https://open.spotify.com/playlist...
# 47  {'spotify': 'https://open.spotify.com/playlist...
# 48  {'spotify': 'https://open.spotify.com/playlist...
# 49  {'spotify': 'https://open.spotify.com/playlist...
#
#                                                  href                      id  \
# 0   https://api.spotify.com/v1/playlists/4788Yhz25...  4788Yhz25ETV8x8yROewmF
# 1   https://api.spotify.com/v1/playlists/7AlwC5VBi...  7AlwC5VBiUMfUPlKl0eRqz
# 2   https://api.spotify.com/v1/playlists/7bj5es8DW...  7bj5es8DWAf8nz90O7olSH
# 3   https://api.spotify.com/v1/playlists/2tCc6aPlf...  2tCc6aPlfCBtKyJq1UrC2Q
# 4   https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1Fa1IIVtEpGUcU
# 5   https://api.spotify.com/v1/playlists/7JservuMd...  7JservuMd38RdUFib5hHjS
# 6   https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DXbITWG1ZJKYt
# 7   https://api.spotify.com/v1/playlists/0vXIPqBfG...  0vXIPqBfGPzBwmii3Lhbn6
# 8   https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DX7YCknf2jT6s
# 9   https://api.spotify.com/v1/playlists/74bhE2qwF...  74bhE2qwFrITyN7bxwBVUf
# 10  https://api.spotify.com/v1/playlists/5GdbhK7zQ...  5GdbhK7zQhKXWVn3rGFgOB
# 11  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DXa8NOEUWPn9W
# 12  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DXdbXrPNafg9d
# 13  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DWWEJlAGA9gs0
# 14  https://api.spotify.com/v1/playlists/37i9dQZF1...  37i9dQZF1DX9G9wwzwWL2k
# 15  https://api.spotify.com/v1/playlists/4C154Jcqf...  4C154JcqfbOPfoEmFtZUHV
# 16  https://api.spotify.com/v1/playlists/5zCM15rmq...  5zCM15rmqjPg1NcVRV9AAK
# 17  https://api.spotify.com/v1/playlists/3CprXA2nv...  3CprXA2nvM7q3dNlYAw8T7
# 18  https://api.spotify.com/v1/playlists/55qI7fmOu...  55qI7fmOuyubCpuyMQe2HA
# 19  https://api.spotify.com/v1/playlists/3wSXaKhQG...  3wSXaKhQGz4N4IejoZDuke
# 20  https://api.spotify.com/v1/playlists/0i4xHphl8...  0i4xHphl86ZvdToqGFLItj
# 21  https://api.spotify.com/v1/playlists/1dMrNE8Zt...  1dMrNE8Ztxn4vbeCcunSrR
# 22  https://api.spotify.com/v1/playlists/4gqsDy7r5...  4gqsDy7r5fIk6Zn9sLCn7Y
# 23  https://api.spotify.com/v1/playlists/35zYgL7BI...  35zYgL7BI5YIyuPrxMCbCb
# 24  https://api.spotify.com/v1/playlists/1JD1H92ID...  1JD1H92IDZjtXLCkBApDXf
# 25  https://api.spotify.com/v1/playlists/73NzgTTPR...  73NzgTTPRmOs8RnghaHvzj
# 26  https://api.spotify.com/v1/playlists/5AgVKKvlk...  5AgVKKvlkzDzFqNUjz675h
# 27  https://api.spotify.com/v1/playlists/1liD0cOhw...  1liD0cOhwTK5g4aDUerQ2d
# 28  https://api.spotify.com/v1/playlists/4gHAyRO6g...  4gHAyRO6gc6CH7Fns3yxdU
# 29  https://api.spotify.com/v1/playlists/160L62PfJ...  160L62PfJxt0p8FBLPeYvJ
# 30  https://api.spotify.com/v1/playlists/7lcAaJLE8...  7lcAaJLE8uzQQKtpYEjwaF
# 31  https://api.spotify.com/v1/playlists/5BgGykm9z...  5BgGykm9z8O3FJ4920EKo6
# 32  https://api.spotify.com/v1/playlists/2jzyt0XNY...  2jzyt0XNYZjLnZt9tb8Isi
# 33  https://api.spotify.com/v1/playlists/6pdsxjJxP...  6pdsxjJxP1F1UMNf9anjNE
# 34  https://api.spotify.com/v1/playlists/0ZqGgjOEf...  0ZqGgjOEfLWMUDFBStzJ0H
# 35  https://api.spotify.com/v1/playlists/30BpbpMQY...  30BpbpMQY1pYueClsulT9L
# 36  https://api.spotify.com/v1/playlists/1e2bFpFa3...  1e2bFpFa3sBqOWj9wY2gAh
# 37  https://api.spotify.com/v1/playlists/6Yqy1ZrPV...  6Yqy1ZrPVjVfa6vxX4cOzq
# 38  https://api.spotify.com/v1/playlists/6Yi7Y5oiY...  6Yi7Y5oiYfb1FS0bulej8n
# 39  https://api.spotify.com/v1/playlists/2fDelR3JT...  2fDelR3JTPwNCIvvSTO8ep
# 40  https://api.spotify.com/v1/playlists/4EkAj71Ej...  4EkAj71Ej6ND7qSUoNAKun
# 41  https://api.spotify.com/v1/playlists/0syjvMGtF...  0syjvMGtFDvBI3benvOav7
# 42  https://api.spotify.com/v1/playlists/2pCZmiUVQ...  2pCZmiUVQMIqnfU9EmiRqW
# 43  https://api.spotify.com/v1/playlists/1AYgIhHPM...  1AYgIhHPMP4ao8zeBllNjo
# 44  https://api.spotify.com/v1/playlists/3bGhQEqWo...  3bGhQEqWo5OGRSoJ6Lb821
# 45  https://api.spotify.com/v1/playlists/72Sd6Gysk...  72Sd6GyskXLgd7eORRYYOD
# 46  https://api.spotify.com/v1/playlists/0mgixVXTb...  0mgixVXTblAYtG4rAAQ6K2
# 47  https://api.spotify.com/v1/playlists/0RAwz93C5...  0RAwz93C50a4tsI5vxMl08
# 48  https://api.spotify.com/v1/playlists/424ZHrR19...  424ZHrR19HbCeykOaKATmu
# 49  https://api.spotify.com/v1/playlists/0H7kQJ6st...  0H7kQJ6stiEoTWln7xclRm
#
#                                                images                  name  \
# 0   [{'height': None, 'url': 'https://i.scdn.co/im...    100th one (B-side)
# 1   [{'height': None, 'url': 'https://image-cdn-ak...             100th one
# 2   [{'height': 640, 'url': 'https://mosaic.scdn.c...                  🌞 ⛱️
# 3   [{'height': 640, 'url': 'https://mosaic.scdn.c...                     🎮
# 4   [{'height': None, 'url': 'https://wrapped-imag...   Your Top Songs 2023
# 5   [{'height': 640, 'url': 'https://mosaic.scdn.c...       Gamer Juice =_=
# 6   [{'height': None, 'url': 'https://i.scdn.co/im...         Jazz Classics
# 7   [{'height': 640, 'url': 'https://mosaic.scdn.c...                  Jazz
# 8   [{'height': None, 'url': 'https://i.scdn.co/im...         State of Jazz
# 9   [{'height': 640, 'url': 'https://mosaic.scdn.c...              Vibetron
# 10  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   EDM
# 11  [{'height': None, 'url': 'https://i.scdn.co/im...             Housewerk
# 12  [{'height': None, 'url': 'https://i.scdn.co/im...         All New Indie
# 13  [{'height': None, 'url': 'https://i.scdn.co/im...  Classical Essentials
# 14  [{'height': None, 'url': 'https://i.scdn.co/im...        Epic Classical
# 15  [{'height': 640, 'url': 'https://mosaic.scdn.c...             Classical
# 16  [{'height': 640, 'url': 'https://mosaic.scdn.c...                 juice
# 17  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   99😲
# 18  [{'height': 640, 'url': 'https://mosaic.scdn.c...                 98👨‍🍳
# 19  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   97🤨
# 20  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   96👶
# 21  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   95🍞
# 22  [{'height': 640, 'url': 'https://mosaic.scdn.c...                 94🌬️🍃
# 23  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   93🌀
# 24  [{'height': 640, 'url': 'https://mosaic.scdn.c...                 92.2📉
# 25  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   92📈
# 26  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   91⚡
# 27  [{'height': 640, 'url': 'https://mosaic.scdn.c...                  90🕰️
# 28  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   89👻
# 29  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   88🔧
# 30  [{'height': 640, 'url': 'https://mosaic.scdn.c...         Chillimonjaro
# 31  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   87🧠
# 32  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   💪86
# 33  [{'height': 640, 'url': 'https://mosaic.scdn.c...                  85❄️
# 34  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   84🍂
# 35  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   83😳
# 36  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   82😡
# 37  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   81😱
# 38  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   80✊
# 39  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   79😷
# 40  [{'height': 640, 'url': 'https://mosaic.scdn.c...                 POWER
# 41  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   78😔
# 42  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   77😤
# 43  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   76😈
# 44  [{'height': 640, 'url': 'https://mosaic.scdn.c...                   75😍
# 45  [{'height': 640, 'url': 'https://mosaic.scdn.c...                    <3
# 46  [{'height': 640, 'url': 'https://mosaic.scdn.c...                    74
# 47  [{'height': 640, 'url': 'https://mosaic.scdn.c...   🎶on the road again🎵
# 48  [{'height': 640, 'url': 'https://mosaic.scdn.c...                    73
# 49  [{'height': 640, 'url': 'https://mosaic.scdn.c...                    72
#
#                                                 owner primary_color  public  \
# 0   {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 1   {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 2   {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 3   {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 4   {'display_name': 'Spotify', 'external_urls': {...          None    True
# 5   {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 6   {'display_name': 'Spotify', 'external_urls': {...       #ffffff    True
# 7   {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 8   {'display_name': 'Spotify', 'external_urls': {...       #ffffff    True
# 9   {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 10  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 11  {'display_name': 'Spotify', 'external_urls': {...       #c3c1c1    True
# 12  {'display_name': 'Spotify', 'external_urls': {...       #FFFFFF    True
# 13  {'display_name': 'Spotify', 'external_urls': {...       #ffffff    True
# 14  {'display_name': 'Spotify', 'external_urls': {...       #ffffff    True
# 15  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 16  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 17  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 18  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 19  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 20  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 21  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 22  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 23  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 24  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 25  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 26  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 27  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 28  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 29  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 30  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 31  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 32  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 33  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 34  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 35  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 36  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 37  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 38  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 39  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 40  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 41  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 42  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 43  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 44  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 45  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 46  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 47  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 48  {'display_name': 'Joel Weber', 'external_urls'...          None    True
# 49  {'display_name': 'Joel Weber', 'external_urls'...          None    True
#
#                          snapshot_id  \
# 0   AAAABNP7quksHVtf85OacuOxdAwnXw1B
# 1   AAAABd9oXW+SLo+npVSclSkQVVmwpM5h
# 2   AAAAKpTzp6wJwxLqvedKPQk+R+5lRGKb
# 3   AAAAQNmReqAP/Q42MFV6TP1W2p2X8OID
# 4   ZVPI2AAAAAD0+Af8jvnvW5Rlb9UA+FT5
# 5   AAAAWs37VfnQiUlfdxZPaSttHMIEjqvn
# 6   ZpepPgAAAADTJfhZWBLe8XWR/539f2YY
# 7   AAAAQDqtM0yS6USqhO4J2amrcP5R7yVe
# 8   Zv9oQAAAAACohQL57mZL4hrj/9xYIHoa
# 9   AAAAS6A/n34hvuX6OtIAYj61TXypT22o
# 10  AAAAIX81Lm8x0ACw4fQF44UtdkRaGYmQ
# 11  Zv9oQAAAAAA7y0MCVUmC2ag9ze6LiBh+
# 12  Zv9oQAAAAAAC6g6LkotaffReytvPTb2t
# 13  ZvZ8TQAAAADNzWgnAJ6W0TfBh2XBrg1e
# 14  ZvbACgAAAAAdFqI0CZI8tHsFnuB2rsWE
# 15  AAAA7n+CqiJC6K2b+xC0oPczkFZPzUmM
# 16  AAABAYKIYVHSI9akn6XaFDlTZOhkxTeb
# 17  AAABWkSrrS8wIlYHHR9IFSHslQyQPWrY
# 18  AAAAOBuE8XM54ZEckqIjx5ZC83HjrBfe
# 19  AAAAmRy2QwdeJorVQ0tfW6fDjQsJF+BT
# 20  AAAAZO4Uwl1I9ufVEOMabV1mNeN3o6Wo
# 21  AAAAZYkj4HIHkmPOXo50w6FTqQmxe76L
# 22  AAAAbSL9/n+m2hXYWy4+BgTsRf0ru/yP
# 23  AAAAF2BEfm54pwfe9WM8yPfc0XY6DTHl
# 24  AAAABalcNcEFRyfPcM6eqx6N886YfmzA
# 25  AAAAWYx+VF9Qi+tfINtAHsc8clpQOdB4
# 26  AAAAw2hH8Fw/VTeFDcMmFbEPloE5gJmf
# 27  AAAAUp2QfIlZQyg3C+SgfnuAo7ZYAxA4
# 28  AAAAPVsfViCuISkkPMh8HzYVHfzsYcVt
# 29  AAAAZXb1vnsGsnBz2o9UNFJIEm5PpY9O
# 30  AAAABB/+1+ealy+k+yIOkTRPYKcXAKGm
# 31  AAAAUyET0WHX7gNOZ9LkQHe9G2g2J/F9
# 32  AAAAVPrylsFvWu6p8DII+E0HRB8OtTY/
# 33  AAAAYchT+Sigb5PU3BcOlBxGHvd1bma/
# 34  AAAALuVRSjpTpVnf+HE64h2NAcKh4Q3n
# 35  AAAAWh30kUVwrxwmbhVkchpOk2O64wiC
# 36  AAAAb5LHNkpVPTd/u3ChrJL0KiosawGu
# 37  AAAADQu6XdNkFwKC6IllksrRduMQDFyu
# 38  AAAAPgUeB9Z5xhqrwXedezDfqiqvKafN
# 39  AAAAUmI5EacgI9cwliGsCpigguKoHZwF
# 40  AAAAESkap5uE+A29pJhWcbWg+Fi364UK
# 41  AAAAMiv27WnXQSm9ZiIwVgULoZ2zsgDx
# 42  AAAAXMuJGzKGZ5DWXDqDWRbX9Qo47YjH
# 43  AAAAMI42wBKzR6PXYDNILUyNmRLr6Oz3
# 44  AAAAWjKFxYOfUezHex7HrHDv1jd0hWCs
# 45  AAAAKmUIrYWpI+OUEJK9nFZDlCLFIdjN
# 46  AAAApu+A9kFlJecGvJRCtHR9XqPRJPrk
# 47  AAAAF3PI9bJq0CQdVR8x3vV+TbgOOyBy
# 48  AAAAacvKhh/+fSzJLeR9rWlAjH8GRixJ
# 49  AAAAhQb55bCnmMboHaQNgVpdampFX1Jh
#
#                                                tracks      type  \
# 0   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 1   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 2   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 3   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 4   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 5   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 6   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 7   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 8   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 9   {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 10  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 11  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 12  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 13  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 14  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 15  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 16  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 17  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 18  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 19  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 20  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 21  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 22  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 23  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 24  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 25  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 26  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 27  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 28  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 29  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 30  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 31  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 32  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 33  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 34  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 35  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 36  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 37  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 38  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 39  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 40  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 41  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 42  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 43  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 44  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 45  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 46  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 47  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 48  {'href': 'https://api.spotify.com/v1/playlists...  playlist
# 49  {'href': 'https://api.spotify.com/v1/playlists...  playlist
#
#                                         uri
# 0   spotify:playlist:4788Yhz25ETV8x8yROewmF
# 1   spotify:playlist:7AlwC5VBiUMfUPlKl0eRqz
# 2   spotify:playlist:7bj5es8DWAf8nz90O7olSH
# 3   spotify:playlist:2tCc6aPlfCBtKyJq1UrC2Q
# 4   spotify:playlist:37i9dQZF1Fa1IIVtEpGUcU
# 5   spotify:playlist:7JservuMd38RdUFib5hHjS
# 6   spotify:playlist:37i9dQZF1DXbITWG1ZJKYt
# 7   spotify:playlist:0vXIPqBfGPzBwmii3Lhbn6
# 8   spotify:playlist:37i9dQZF1DX7YCknf2jT6s
# 9   spotify:playlist:74bhE2qwFrITyN7bxwBVUf
# 10  spotify:playlist:5GdbhK7zQhKXWVn3rGFgOB
# 11  spotify:playlist:37i9dQZF1DXa8NOEUWPn9W
# 12  spotify:playlist:37i9dQZF1DXdbXrPNafg9d
# 13  spotify:playlist:37i9dQZF1DWWEJlAGA9gs0
# 14  spotify:playlist:37i9dQZF1DX9G9wwzwWL2k
# 15  spotify:playlist:4C154JcqfbOPfoEmFtZUHV
# 16  spotify:playlist:5zCM15rmqjPg1NcVRV9AAK
# 17  spotify:playlist:3CprXA2nvM7q3dNlYAw8T7
# 18  spotify:playlist:55qI7fmOuyubCpuyMQe2HA
# 19  spotify:playlist:3wSXaKhQGz4N4IejoZDuke
# 20  spotify:playlist:0i4xHphl86ZvdToqGFLItj
# 21  spotify:playlist:1dMrNE8Ztxn4vbeCcunSrR
# 22  spotify:playlist:4gqsDy7r5fIk6Zn9sLCn7Y
# 23  spotify:playlist:35zYgL7BI5YIyuPrxMCbCb
# 24  spotify:playlist:1JD1H92IDZjtXLCkBApDXf
# 25  spotify:playlist:73NzgTTPRmOs8RnghaHvzj
# 26  spotify:playlist:5AgVKKvlkzDzFqNUjz675h
# 27  spotify:playlist:1liD0cOhwTK5g4aDUerQ2d
# 28  spotify:playlist:4gHAyRO6gc6CH7Fns3yxdU
# 29  spotify:playlist:160L62PfJxt0p8FBLPeYvJ
# 30  spotify:playlist:7lcAaJLE8uzQQKtpYEjwaF
# 31  spotify:playlist:5BgGykm9z8O3FJ4920EKo6
# 32  spotify:playlist:2jzyt0XNYZjLnZt9tb8Isi
# 33  spotify:playlist:6pdsxjJxP1F1UMNf9anjNE
# 34  spotify:playlist:0ZqGgjOEfLWMUDFBStzJ0H
# 35  spotify:playlist:30BpbpMQY1pYueClsulT9L
# 36  spotify:playlist:1e2bFpFa3sBqOWj9wY2gAh
# 37  spotify:playlist:6Yqy1ZrPVjVfa6vxX4cOzq
# 38  spotify:playlist:6Yi7Y5oiYfb1FS0bulej8n
# 39  spotify:playlist:2fDelR3JTPwNCIvvSTO8ep
# 40  spotify:playlist:4EkAj71Ej6ND7qSUoNAKun
# 41  spotify:playlist:0syjvMGtFDvBI3benvOav7
# 42  spotify:playlist:2pCZmiUVQMIqnfU9EmiRqW
# 43  spotify:playlist:1AYgIhHPMP4ao8zeBllNjo
# 44  spotify:playlist:3bGhQEqWo5OGRSoJ6Lb821
# 45  spotify:playlist:72Sd6GyskXLgd7eORRYYOD
# 46  spotify:playlist:0mgixVXTblAYtG4rAAQ6K2
# 47  spotify:playlist:0RAwz93C50a4tsI5vxMl08
# 48  spotify:playlist:424ZHrR19HbCeykOaKATmu
# 49  spotify:playlist:0H7kQJ6stiEoTWln7xclRm

# %%
songs = sp.playlist_items(playlist_id='3CprXA2nvM7q3dNlYAw8T7', market =None)

# %%
songs
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/3CprXA2nvM7q3dNlYAw8T7/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2023-03-10T22:45:51Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/35471f919b054a2e2798fb4a47b2b5f67181eb2f?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/5wj4dMktjUCPq8BfsQCMR2',
#      'id': '5wj4dMktjUCPq8BfsQCMR2',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27320e1128855ce92371fdd9744',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0220e1128855ce92371fdd9744',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485120e1128855ce92371fdd9744',
#        'width': 64}],
#      'name': 'Someone You Can Count On',
#      'release_date': '2023-03-08',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:5wj4dMktjUCPq8BfsQCMR2',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CMaNobmJYgXcfiT0zYOwi'},
#        'href': 'https://api.spotify.com/v1/artists/5CMaNobmJYgXcfiT0zYOwi',
#        'id': '5CMaNobmJYgXcfiT0zYOwi',
#        'name': 'WHIPPED CREAM',
#        'type': 'artist',
#        'uri': 'spotify:artist:5CMaNobmJYgXcfiT0zYOwi'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/5wj4dMktjUCPq8BfsQCMR2'},
#      'total_tracks': 7},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5CMaNobmJYgXcfiT0zYOwi'},
#       'href': 'https://api.spotify.com/v1/artists/5CMaNobmJYgXcfiT0zYOwi',
#       'id': '5CMaNobmJYgXcfiT0zYOwi',
#       'name': 'WHIPPED CREAM',
#       'type': 'artist',
#       'uri': 'spotify:artist:5CMaNobmJYgXcfiT0zYOwi'}],
#     'disc_number': 1,
#     'track_number': 2,
#     'duration_ms': 197647,
#     'external_ids': {'isrc': 'CA6D22200425'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0gewlgiKXqSUzvuKaiazWe'},
#     'href': 'https://api.spotify.com/v1/tracks/0gewlgiKXqSUzvuKaiazWe',
#     'id': '0gewlgiKXqSUzvuKaiazWe',
#     'name': 'Angels',
#     'popularity': 15,
#     'uri': 'spotify:track:0gewlgiKXqSUzvuKaiazWe',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-10T22:50:21Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/1cce06be1e8bc6d30ee8f6e00e4ac1f6d5d58b52?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/3VvPLpCZR5viLBFTbzm6E1',
#      'id': '3VvPLpCZR5viLBFTbzm6E1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731e28b92ccb915b5307a7eb02',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021e28b92ccb915b5307a7eb02',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511e28b92ccb915b5307a7eb02',
#        'width': 64}],
#      'name': 'Watch This (ARIZONATEARS Pluggnb Remix)',
#      'release_date': '2023-02-05',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3VvPLpCZR5viLBFTbzm6E1',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4O15NlyKLIASxsJ0PrXPfz'},
#        'href': 'https://api.spotify.com/v1/artists/4O15NlyKLIASxsJ0PrXPfz',
#        'id': '4O15NlyKLIASxsJ0PrXPfz',
#        'name': 'Lil Uzi Vert',
#        'type': 'artist',
#        'uri': 'spotify:artist:4O15NlyKLIASxsJ0PrXPfz'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/0M2CO5ijP35MDhNwvpgxTV'},
#        'href': 'https://api.spotify.com/v1/artists/0M2CO5ijP35MDhNwvpgxTV',
#        'id': '0M2CO5ijP35MDhNwvpgxTV',
#        'name': 'sped up nightcore',
#        'type': 'artist',
#        'uri': 'spotify:artist:0M2CO5ijP35MDhNwvpgxTV'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/2xzyIzdjfeXX6FIQtlAAyw'},
#        'href': 'https://api.spotify.com/v1/artists/2xzyIzdjfeXX6FIQtlAAyw',
#        'id': '2xzyIzdjfeXX6FIQtlAAyw',
#        'name': 'ARIZONATEARS',
#        'type': 'artist',
#        'uri': 'spotify:artist:2xzyIzdjfeXX6FIQtlAAyw'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3VvPLpCZR5viLBFTbzm6E1'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4O15NlyKLIASxsJ0PrXPfz'},
#       'href': 'https://api.spotify.com/v1/artists/4O15NlyKLIASxsJ0PrXPfz',
#       'id': '4O15NlyKLIASxsJ0PrXPfz',
#       'name': 'Lil Uzi Vert',
#       'type': 'artist',
#       'uri': 'spotify:artist:4O15NlyKLIASxsJ0PrXPfz'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0M2CO5ijP35MDhNwvpgxTV'},
#       'href': 'https://api.spotify.com/v1/artists/0M2CO5ijP35MDhNwvpgxTV',
#       'id': '0M2CO5ijP35MDhNwvpgxTV',
#       'name': 'sped up nightcore',
#       'type': 'artist',
#       'uri': 'spotify:artist:0M2CO5ijP35MDhNwvpgxTV'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/2xzyIzdjfeXX6FIQtlAAyw'},
#       'href': 'https://api.spotify.com/v1/artists/2xzyIzdjfeXX6FIQtlAAyw',
#       'id': '2xzyIzdjfeXX6FIQtlAAyw',
#       'name': 'ARIZONATEARS',
#       'type': 'artist',
#       'uri': 'spotify:artist:2xzyIzdjfeXX6FIQtlAAyw'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 163139,
#     'external_ids': {'isrc': 'USAT22301358'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0FA4wrjDJvJTTU8AepZTup'},
#     'href': 'https://api.spotify.com/v1/tracks/0FA4wrjDJvJTTU8AepZTup',
#     'id': '0FA4wrjDJvJTTU8AepZTup',
#     'name': 'Watch This - ARIZONATEARS Pluggnb Remix',
#     'popularity': 76,
#     'uri': 'spotify:track:0FA4wrjDJvJTTU8AepZTup',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-12T20:04:26Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/c69cf6ed41027bd08a5953b556cca144ff8ed2bf?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/70xdtgH5XuYTqBNdNbUwGO',
#      'id': '70xdtgH5XuYTqBNdNbUwGO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2735e8286ff63f7efce1881a02b',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e025e8286ff63f7efce1881a02b',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048515e8286ff63f7efce1881a02b',
#        'width': 64}],
#      'name': 'on the street (with J. Cole)',
#      'release_date': '2023-03-03',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:70xdtgH5XuYTqBNdNbUwGO',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0b1sIQumIAsNbqAoIClSpy'},
#        'href': 'https://api.spotify.com/v1/artists/0b1sIQumIAsNbqAoIClSpy',
#        'id': '0b1sIQumIAsNbqAoIClSpy',
#        'name': 'j-hope',
#        'type': 'artist',
#        'uri': 'spotify:artist:0b1sIQumIAsNbqAoIClSpy'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#        'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#        'id': '6l3HvQ5sa6mXTsMTB19rO5',
#        'name': 'J. Cole',
#        'type': 'artist',
#        'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/70xdtgH5XuYTqBNdNbUwGO'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0b1sIQumIAsNbqAoIClSpy'},
#       'href': 'https://api.spotify.com/v1/artists/0b1sIQumIAsNbqAoIClSpy',
#       'id': '0b1sIQumIAsNbqAoIClSpy',
#       'name': 'j-hope',
#       'type': 'artist',
#       'uri': 'spotify:artist:0b1sIQumIAsNbqAoIClSpy'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6l3HvQ5sa6mXTsMTB19rO5'},
#       'href': 'https://api.spotify.com/v1/artists/6l3HvQ5sa6mXTsMTB19rO5',
#       'id': '6l3HvQ5sa6mXTsMTB19rO5',
#       'name': 'J. Cole',
#       'type': 'artist',
#       'uri': 'spotify:artist:6l3HvQ5sa6mXTsMTB19rO5'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 214701,
#     'external_ids': {'isrc': 'USA2P2251898'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5wxYxygyHpbgv0EXZuqb9V'},
#     'href': 'https://api.spotify.com/v1/tracks/5wxYxygyHpbgv0EXZuqb9V',
#     'id': '5wxYxygyHpbgv0EXZuqb9V',
#     'name': 'on the street (with J. Cole)',
#     'popularity': 65,
#     'uri': 'spotify:track:5wxYxygyHpbgv0EXZuqb9V',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-16T22:45:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/043dde993e54b4a443462aefb66fbe58ef1d860a?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': [],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': [],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/37b8oZGEqxo6EUcOLnx9TG',
#      'id': '37b8oZGEqxo6EUcOLnx9TG',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cd0dba775de2dabd1925dd3d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cd0dba775de2dabd1925dd3d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cd0dba775de2dabd1925dd3d',
#        'width': 64}],
#      'name': 'The Reset',
#      'release_date': '2022-11-11',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:37b8oZGEqxo6EUcOLnx9TG',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4p5WgeiPSPpqPDs7T6OkWf'},
#        'href': 'https://api.spotify.com/v1/artists/4p5WgeiPSPpqPDs7T6OkWf',
#        'id': '4p5WgeiPSPpqPDs7T6OkWf',
#        'name': 'ANOTR',
#        'type': 'artist',
#        'uri': 'spotify:artist:4p5WgeiPSPpqPDs7T6OkWf'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/37b8oZGEqxo6EUcOLnx9TG'},
#      'total_tracks': 12},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4p5WgeiPSPpqPDs7T6OkWf'},
#       'href': 'https://api.spotify.com/v1/artists/4p5WgeiPSPpqPDs7T6OkWf',
#       'id': '4p5WgeiPSPpqPDs7T6OkWf',
#       'name': 'ANOTR',
#       'type': 'artist',
#       'uri': 'spotify:artist:4p5WgeiPSPpqPDs7T6OkWf'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/0jqbEIAvdjUOi5Za48pzQG'},
#       'href': 'https://api.spotify.com/v1/artists/0jqbEIAvdjUOi5Za48pzQG',
#       'id': '0jqbEIAvdjUOi5Za48pzQG',
#       'name': 'Abel Balder',
#       'type': 'artist',
#       'uri': 'spotify:artist:0jqbEIAvdjUOi5Za48pzQG'}],
#     'disc_number': 1,
#     'track_number': 12,
#     'duration_ms': 191053,
#     'external_ids': {'isrc': 'GBKQU2296427'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1J3C8kdqUckBrTtgttm0AA'},
#     'href': 'https://api.spotify.com/v1/tracks/1J3C8kdqUckBrTtgttm0AA',
#     'id': '1J3C8kdqUckBrTtgttm0AA',
#     'name': 'Relax My Eyes',
#     'popularity': 0,
#     'uri': 'spotify:track:1J3C8kdqUckBrTtgttm0AA',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-17T01:07:49Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/de9809d44533e84dfdab26e27f3d37b71471706d?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/6YoiqsdphEsZXtzscOpk5x',
#      'id': '6YoiqsdphEsZXtzscOpk5x',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273e5162939d441f51680eb481f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02e5162939d441f51680eb481f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851e5162939d441f51680eb481f',
#        'width': 64}],
#      'name': 'Mirage',
#      'release_date': '2016-01-25',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6YoiqsdphEsZXtzscOpk5x',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tUUqZeqBYInHt3aDp3a1B'},
#        'href': 'https://api.spotify.com/v1/artists/2tUUqZeqBYInHt3aDp3a1B',
#        'id': '2tUUqZeqBYInHt3aDp3a1B',
#        'name': 'Else',
#        'type': 'artist',
#        'uri': 'spotify:artist:2tUUqZeqBYInHt3aDp3a1B'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6YoiqsdphEsZXtzscOpk5x'},
#      'total_tracks': 6},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2tUUqZeqBYInHt3aDp3a1B'},
#       'href': 'https://api.spotify.com/v1/artists/2tUUqZeqBYInHt3aDp3a1B',
#       'id': '2tUUqZeqBYInHt3aDp3a1B',
#       'name': 'Else',
#       'type': 'artist',
#       'uri': 'spotify:artist:2tUUqZeqBYInHt3aDp3a1B'}],
#     'disc_number': 1,
#     'track_number': 3,
#     'duration_ms': 237397,
#     'external_ids': {'isrc': 'FR9W11600525'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1KsKIbwhMyQyWpNpNPCfcH'},
#     'href': 'https://api.spotify.com/v1/tracks/1KsKIbwhMyQyWpNpNPCfcH',
#     'id': '1KsKIbwhMyQyWpNpNPCfcH',
#     'name': 'Mirage',
#     'popularity': 27,
#     'uri': 'spotify:track:1KsKIbwhMyQyWpNpNPCfcH',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-18T01:34:15Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/279341f0ecfec45ddf1d0ca74fa29ca9067a5443?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/6Qi8Hf2PW97oZP2a4Tvd24',
#      'id': '6Qi8Hf2PW97oZP2a4Tvd24',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731e725a85985f8279f466ccab',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021e725a85985f8279f466ccab',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511e725a85985f8279f466ccab',
#        'width': 64}],
#      'name': 'Kant Nobody',
#      'release_date': '2023-02-23',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:6Qi8Hf2PW97oZP2a4Tvd24',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55Aa2cqylxrFIXC767Z865'},
#        'href': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865',
#        'id': '55Aa2cqylxrFIXC767Z865',
#        'name': 'Lil Wayne',
#        'type': 'artist',
#        'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6Qi8Hf2PW97oZP2a4Tvd24'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/55Aa2cqylxrFIXC767Z865'},
#       'href': 'https://api.spotify.com/v1/artists/55Aa2cqylxrFIXC767Z865',
#       'id': '55Aa2cqylxrFIXC767Z865',
#       'name': 'Lil Wayne',
#       'type': 'artist',
#       'uri': 'spotify:artist:55Aa2cqylxrFIXC767Z865'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/1HwM5zlC5qNWhJtM00yXzG'},
#       'href': 'https://api.spotify.com/v1/artists/1HwM5zlC5qNWhJtM00yXzG',
#       'id': '1HwM5zlC5qNWhJtM00yXzG',
#       'name': 'DMX',
#       'type': 'artist',
#       'uri': 'spotify:artist:1HwM5zlC5qNWhJtM00yXzG'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 180359,
#     'external_ids': {'isrc': 'USUG12301293'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ehLKvUsJq3EUAPpvT5GOM'},
#     'href': 'https://api.spotify.com/v1/tracks/2ehLKvUsJq3EUAPpvT5GOM',
#     'id': '2ehLKvUsJq3EUAPpvT5GOM',
#     'name': 'Kant Nobody (feat. DMX)',
#     'popularity': 48,
#     'uri': 'spotify:track:2ehLKvUsJq3EUAPpvT5GOM',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-19T22:07:53Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/47994b8a4180140c15a3ece369c3c1dd02768e9f?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'single',
#      'href': 'https://api.spotify.com/v1/albums/4fM1JysLcYDX9No45tZmqO',
#      'id': '4fM1JysLcYDX9No45tZmqO',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273ec748231035512e229a1376e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02ec748231035512e229a1376e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851ec748231035512e229a1376e',
#        'width': 64}],
#      'name': 'Vuelve',
#      'release_date': '2017-09-29',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:4fM1JysLcYDX9No45tZmqO',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#        'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#        'id': '4VMYDCV2IEDYJArk749S6m',
#        'name': 'Daddy Yankee',
#        'type': 'artist',
#        'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#        'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#        'id': '4q3ewBCX7sLwd24euuV69X',
#        'name': 'Bad Bunny',
#        'type': 'artist',
#        'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/4fM1JysLcYDX9No45tZmqO'},
#      'total_tracks': 1},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4VMYDCV2IEDYJArk749S6m'},
#       'href': 'https://api.spotify.com/v1/artists/4VMYDCV2IEDYJArk749S6m',
#       'id': '4VMYDCV2IEDYJArk749S6m',
#       'name': 'Daddy Yankee',
#       'type': 'artist',
#       'uri': 'spotify:artist:4VMYDCV2IEDYJArk749S6m'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/4q3ewBCX7sLwd24euuV69X'},
#       'href': 'https://api.spotify.com/v1/artists/4q3ewBCX7sLwd24euuV69X',
#       'id': '4q3ewBCX7sLwd24euuV69X',
#       'name': 'Bad Bunny',
#       'type': 'artist',
#       'uri': 'spotify:artist:4q3ewBCX7sLwd24euuV69X'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 279613,
#     'external_ids': {'isrc': 'US2BU1700915'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0gCPvo1GkbtPhMqg5Gbx1K'},
#     'href': 'https://api.spotify.com/v1/tracks/0gCPvo1GkbtPhMqg5Gbx1K',
#     'id': '0gCPvo1GkbtPhMqg5Gbx1K',
#     'name': 'Vuelve',
#     'popularity': 73,
#     'uri': 'spotify:track:0gCPvo1GkbtPhMqg5Gbx1K',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-23T02:31:05Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/da5aef918f35bfe2b1673e4ca0de7da9a735116e?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['AR',
#      'AU',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
# ...
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3u20OXh03DjCUzbf8XcGTq',
#      'id': '3u20OXh03DjCUzbf8XcGTq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738cf4c85912fdeb106707fb4c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028cf4c85912fdeb106707fb4c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518cf4c85912fdeb106707fb4c',
#        'width': 64}],
#      'name': 'SCARING THE HOES',
#      'release_date': '2023-03-24',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3u20OXh03DjCUzbf8XcGTq',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yJ6QQ3Y5l0s0tn7b0arrO'},
#        'href': 'https://api.spotify.com/v1/artists/6yJ6QQ3Y5l0s0tn7b0arrO',
#        'id': '6yJ6QQ3Y5l0s0tn7b0arrO',
#        'name': 'JPEGMAFIA',
#        'type': 'artist',
#        'uri': 'spotify:artist:6yJ6QQ3Y5l0s0tn7b0arrO'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aA592KWirLsnfb5ulGWvU'},
#        'href': 'https://api.spotify.com/v1/artists/7aA592KWirLsnfb5ulGWvU',
#        'id': '7aA592KWirLsnfb5ulGWvU',
#        'name': 'Danny Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:7aA592KWirLsnfb5ulGWvU'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3u20OXh03DjCUzbf8XcGTq'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yJ6QQ3Y5l0s0tn7b0arrO'},
#       'href': 'https://api.spotify.com/v1/artists/6yJ6QQ3Y5l0s0tn7b0arrO',
#       'id': '6yJ6QQ3Y5l0s0tn7b0arrO',
#       'name': 'JPEGMAFIA',
#       'type': 'artist',
#       'uri': 'spotify:artist:6yJ6QQ3Y5l0s0tn7b0arrO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aA592KWirLsnfb5ulGWvU'},
#       'href': 'https://api.spotify.com/v1/artists/7aA592KWirLsnfb5ulGWvU',
#       'id': '7aA592KWirLsnfb5ulGWvU',
#       'name': 'Danny Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7aA592KWirLsnfb5ulGWvU'}],
#     'disc_number': 1,
#     'track_number': 13,
#     'duration_ms': 203809,
#     'external_ids': {'isrc': 'QM4TX2336701'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4vL0V5MjU3Y1syYtajWW4f'},
#     'href': 'https://api.spotify.com/v1/tracks/4vL0V5MjU3Y1syYtajWW4f',
#     'id': '4vL0V5MjU3Y1syYtajWW4f',
#     'name': 'HOE (Heaven on Earth)',
#     'popularity': 46,
#     'uri': 'spotify:track:4vL0V5MjU3Y1syYtajWW4f',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-27T13:52:38Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/b4a6991c8fd5a26ad0c9626a9f5eaf09a22b5406?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
#      'MX',
#      'NL',
#      'NZ',
#      'NI',
#      'NO',
#      'PA',
#      'PY',
#      'PE',
#      'PH',
#      'PL',
#      'PT',
#      'SG',
#      'SK',
#      'ES',
#      'SE',
#      'CH',
#      'TW',
#      'TR',
#      'UY',
#      'US',
#      'GB',
#      'AD',
#      'LI',
#      'MC',
#      'ID',
#      'JP',
#      'TH',
#      'VN',
#      'RO',
#      'IL',
#      'ZA',
#      'SA',
#      'AE',
#      'BH',
#      'QA',
#      'OM',
#      'KW',
#      'EG',
#      'MA',
#      'DZ',
#      'TN',
#      'LB',
#      'JO',
#      'PS',
#      'IN',
#      'BY',
#      'KZ',
#      'MD',
#      'UA',
#      'AL',
#      'BA',
#      'HR',
#      'ME',
#      'MK',
#      'RS',
#      'SI',
#      'KR',
#      'BD',
#      'PK',
#      'LK',
#      'GH',
#      'KE',
#      'NG',
#      'TZ',
#      'UG',
#      'AG',
#      'AM',
#      'BS',
#      'BB',
#      'BZ',
#      'BT',
#      'BW',
#      'BF',
#      'CV',
#      'CW',
#      'DM',
#      'FJ',
#      'GM',
#      'GE',
#      'GD',
#      'GW',
#      'GY',
#      'HT',
#      'JM',
#      'KI',
#      'LS',
#      'LR',
#      'MW',
#      'MV',
#      'ML',
#      'MH',
#      'FM',
#      'NA',
#      'NR',
#      'NE',
#      'PW',
#      'PG',
#      'PR',
#      'WS',
#      'SM',
#      'ST',
#      'SN',
#      'SC',
#      'SL',
#      'SB',
#      'KN',
#      'LC',
#      'VC',
#      'SR',
#      'TL',
#      'TO',
#      'TT',
#      'TV',
#      'VU',
#      'AZ',
#      'BN',
#      'BI',
#      'KH',
#      'CM',
#      'TD',
#      'KM',
#      'GQ',
#      'SZ',
#      'GA',
#      'GN',
#      'KG',
#      'LA',
#      'MO',
#      'MR',
#      'MN',
#      'NP',
#      'RW',
#      'TG',
#      'UZ',
#      'ZW',
#      'BJ',
#      'MG',
#      'MU',
#      'MZ',
#      'AO',
#      'CI',
#      'DJ',
#      'ZM',
#      'CD',
#      'CG',
#      'IQ',
#      'LY',
#      'TJ',
#      'VE',
#      'ET',
#      'XK'],
#     'explicit': True,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
#       'GT',
#       'HN',
#       'HK',
#       'HU',
#       'IS',
#       'IE',
#       'IT',
#       'LV',
#       'LT',
#       'LU',
#       'MY',
#       'MT',
#       'MX',
#       'NL',
#       'NZ',
#       'NI',
#       'NO',
#       'PA',
#       'PY',
#       'PE',
#       'PH',
#       'PL',
#       'PT',
#       'SG',
#       'SK',
#       'ES',
#       'SE',
#       'CH',
#       'TW',
#       'TR',
#       'UY',
#       'US',
#       'GB',
#       'AD',
#       'LI',
#       'MC',
#       'ID',
#       'JP',
#       'TH',
#       'VN',
#       'RO',
#       'IL',
#       'ZA',
#       'SA',
#       'AE',
#       'BH',
#       'QA',
#       'OM',
#       'KW',
#       'EG',
#       'MA',
#       'DZ',
#       'TN',
#       'LB',
#       'JO',
#       'PS',
#       'IN',
#       'BY',
#       'KZ',
#       'MD',
#       'UA',
#       'AL',
#       'BA',
#       'HR',
#       'ME',
#       'MK',
#       'RS',
#       'SI',
#       'KR',
#       'BD',
#       'PK',
#       'LK',
#       'GH',
#       'KE',
#       'NG',
#       'TZ',
#       'UG',
#       'AG',
#       'AM',
#       'BS',
#       'BB',
#       'BZ',
#       'BT',
#       'BW',
#       'BF',
#       'CV',
#       'CW',
#       'DM',
#       'FJ',
#       'GM',
#       'GE',
#       'GD',
#       'GW',
#       'GY',
#       'HT',
#       'JM',
#       'KI',
#       'LS',
#       'LR',
#       'MW',
#       'MV',
#       'ML',
#       'MH',
#       'FM',
#       'NA',
#       'NR',
#       'NE',
#       'PW',
#       'PG',
#       'PR',
#       'WS',
#       'SM',
#       'ST',
#       'SN',
#       'SC',
#       'SL',
#       'SB',
#       'KN',
#       'LC',
#       'VC',
#       'SR',
#       'TL',
#       'TO',
#       'TT',
#       'TV',
#       'VU',
#       'AZ',
#       'BN',
#       'BI',
#       'KH',
#       'CM',
#       'TD',
#       'KM',
#       'GQ',
#       'SZ',
#       'GA',
#       'GN',
#       'KG',
#       'LA',
#       'MO',
#       'MR',
#       'MN',
#       'NP',
#       'RW',
#       'TG',
#       'UZ',
#       'ZW',
#       'BJ',
#       'MG',
#       'MU',
#       'MZ',
#       'AO',
#       'CI',
#       'DJ',
#       'ZM',
#       'CD',
#       'CG',
#       'IQ',
#       'LY',
#       'TJ',
#       'VE',
#       'ET',
#       'XK'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/3u20OXh03DjCUzbf8XcGTq',
#      'id': '3u20OXh03DjCUzbf8XcGTq',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2738cf4c85912fdeb106707fb4c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e028cf4c85912fdeb106707fb4c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048518cf4c85912fdeb106707fb4c',
#        'width': 64}],
#      'name': 'SCARING THE HOES',
#      'release_date': '2023-03-24',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:3u20OXh03DjCUzbf8XcGTq',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yJ6QQ3Y5l0s0tn7b0arrO'},
#        'href': 'https://api.spotify.com/v1/artists/6yJ6QQ3Y5l0s0tn7b0arrO',
#        'id': '6yJ6QQ3Y5l0s0tn7b0arrO',
#        'name': 'JPEGMAFIA',
#        'type': 'artist',
#        'uri': 'spotify:artist:6yJ6QQ3Y5l0s0tn7b0arrO'},
#       {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aA592KWirLsnfb5ulGWvU'},
#        'href': 'https://api.spotify.com/v1/artists/7aA592KWirLsnfb5ulGWvU',
#        'id': '7aA592KWirLsnfb5ulGWvU',
#        'name': 'Danny Brown',
#        'type': 'artist',
#        'uri': 'spotify:artist:7aA592KWirLsnfb5ulGWvU'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3u20OXh03DjCUzbf8XcGTq'},
#      'total_tracks': 14},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6yJ6QQ3Y5l0s0tn7b0arrO'},
#       'href': 'https://api.spotify.com/v1/artists/6yJ6QQ3Y5l0s0tn7b0arrO',
#       'id': '6yJ6QQ3Y5l0s0tn7b0arrO',
#       'name': 'JPEGMAFIA',
#       'type': 'artist',
#       'uri': 'spotify:artist:6yJ6QQ3Y5l0s0tn7b0arrO'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/7aA592KWirLsnfb5ulGWvU'},
#       'href': 'https://api.spotify.com/v1/artists/7aA592KWirLsnfb5ulGWvU',
#       'id': '7aA592KWirLsnfb5ulGWvU',
#       'name': 'Danny Brown',
#       'type': 'artist',
#       'uri': 'spotify:artist:7aA592KWirLsnfb5ulGWvU'}],
#     'disc_number': 1,
#     'track_number': 14,
#     'duration_ms': 177840,
#     'external_ids': {'isrc': 'QM4TX2336706'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6XITRM4V1hVSQXw62diAoj'},
#     'href': 'https://api.spotify.com/v1/tracks/6XITRM4V1hVSQXw62diAoj',
#     'id': '6XITRM4V1hVSQXw62diAoj',
#     'name': 'Where Ya Get Ya Coke From?',
#     'popularity': 43,
#     'uri': 'spotify:track:6XITRM4V1hVSQXw62diAoj',
#     'is_local': False},
#    'video_thumbnail': {'url': None}},
#   {'added_at': '2023-03-31T20:24:33Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/1216338953'},
#     'href': 'https://api.spotify.com/v1/users/1216338953',
#     'id': '1216338953',
#     'type': 'user',
#     'uri': 'spotify:user:1216338953'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': 'https://p.scdn.co/mp3-preview/78b2640b5577a3eb2ebee6c6c8e71fa9ad4a1719?cid=24875d0445b741e9ba31b55cb20cb999',
#     'available_markets': ['CA', 'PR', 'US'],
#     'explicit': False,
#     'type': 'track',
#     'episode': False,
#     'track': True,
#     'album': {'available_markets': ['CA', 'PR', 'US'],
#      'type': 'album',
#      'album_type': 'album',
#      'href': 'https://api.spotify.com/v1/albums/7B6lEObl7aYkMjX8M89IRQ',
#      'id': '7B6lEObl7aYkMjX8M89IRQ',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273de86635ca5a1a00b4fa80c9c',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02de86635ca5a1a00b4fa80c9c',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851de86635ca5a1a00b4fa80c9c',
#        'width': 64}],
#      'name': 'Fantasy',
#      'release_date': '2023-03-17',
#      'release_date_precision': 'day',
#      'uri': 'spotify:album:7B6lEObl7aYkMjX8M89IRQ',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63MQldklfxkjYDoUE4Tppz'},
#        'href': 'https://api.spotify.com/v1/artists/63MQldklfxkjYDoUE4Tppz',
#        'id': '63MQldklfxkjYDoUE4Tppz',
#        'name': 'M83',
#        'type': 'artist',
#        'uri': 'spotify:artist:63MQldklfxkjYDoUE4Tppz'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7B6lEObl7aYkMjX8M89IRQ'},
#      'total_tracks': 13},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/63MQldklfxkjYDoUE4Tppz'},
#       'href': 'https://api.spotify.com/v1/artists/63MQldklfxkjYDoUE4Tppz',
#       'id': '63MQldklfxkjYDoUE4Tppz',
#       'name': 'M83',
#       'type': 'artist',
#       'uri': 'spotify:artist:63MQldklfxkjYDoUE4Tppz'}],
#     'disc_number': 1,
#     'track_number': 1,
#     'duration_ms': 191356,
#     'external_ids': {'isrc': 'GB5SH2200002'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6IdFHAL5qKY4zZ5sbje8ow'},
#     'href': 'https://api.spotify.com/v1/tracks/6IdFHAL5qKY4zZ5sbje8ow',
#     'id': '6IdFHAL5qKY4zZ5sbje8ow',
#     'name': 'Water Deep',
#     'popularity': 28,
#     'uri': 'spotify:track:6IdFHAL5qKY4zZ5sbje8ow',
#     'is_local': False},
#    'video_thumbnail': {'url': None}}],
#  'limit': 100,
#  'next': 'https://api.spotify.com/v1/playlists/3CprXA2nvM7q3dNlYAw8T7/tracks?offset=100&limit=100&additional_types=track',
#  'offset': 0,
#  'previous': None,
#  'total': 556}
